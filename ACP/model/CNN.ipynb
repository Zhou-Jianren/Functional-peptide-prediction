# %%
# Current directory
import os
os.chdir('F:/One/ACP')

# %% [markdown]
# ### Loading Data

# %%
import numpy as np
import pandas as pd


# train
train_features = pd.read_csv("features_label/train.csv", index_col=False, header=None)
train_labels = pd.read_csv("features_label/train_label.csv", index_col=False, header=None)
# test
test_features = pd.read_csv("features_label/test.csv", index_col=False, header=None)
test_labels = pd.read_csv("features_label/test_label.csv", index_col=False, header=None)

print('train_features:', train_features.shape)
print('train_labels', train_labels.shape)
print('test_features', test_features.shape)
print('test_labels', test_labels.shape)


train_features = np.array(train_features)
train_labels = np.array(train_labels)
test_features = np.array(test_features)
test_labels = np.array(test_labels)
# Out:
# train_features: (1378, 320)
# train_labels (1378, 1)
# test_features (344, 320)
# test_labels (344, 1)

# %% [markdown]
# ### Loading the model

# %%
import math
import statistics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.layers import Flatten
from keras.models import Sequential
from keras.optimizers import adam_v2
from keras.layers import Dense,Dropout
from sklearn.preprocessing import scale
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from keras.layers import Conv1D, Dense,AveragePooling1D
from sklearn.metrics import confusion_matrix, roc_curve, auc


# model
def CNN(input_dim, out_dim, learning_rate=0.001):
    model = Sequential()
    model.add(Conv1D(filters = 64, kernel_size = 3, padding = 'same', activation= 'relu'))
    model.add(AveragePooling1D(pool_size=2,strides=1,padding="SAME"))
    model.add(Conv1D(filters = 64, kernel_size =  3, padding = 'same', activation= 'relu'))
    model.add(AveragePooling1D(pool_size=2,strides=1,padding="SAME"))
    model.add(Flatten())
    model.add(Dense(int(32), activation = 'relu'))
    model.add(Dense(out_dim, activation = 'softmax',name="Dense_2"))
    model.compile(loss = 'binary_crossentropy', optimizer = adam_v2.Adam(learning_rate), metrics =['accuracy'])
    return model


def categorical_probas_to_classes(p):
    return np.argmax(p, axis=1)


def to_categorical(y, nb_classes=None):
    y = np.array(y, dtype='int')
    if not nb_classes:
        nb_classes = np.max(y)+1
    Y = np.zeros((len(y), nb_classes))
    for i in range(len(y)):
        Y[i, y[i]] = 1
    return Y

# %% [markdown]
# ### Training and prediction

# %% [markdown]
# #### Independence test

# %%
# Create a directory to save the model
model_save_dir = 'save_models/CNN/Independence'
os.makedirs(model_save_dir, exist_ok=True)

# %%
[sample_num, input_dim] = np.shape(train_features)
X_train = np.reshape(train_features, (-1,1,input_dim))
y_train = train_labels
X_test = np.reshape(test_features, (-1,1,input_dim))
y_test = test_labels
out_dim=2

ACC_collecton = []
BACC_collecton = []
Sn_collecton = []
Sp_collecton = []
MCC_collecton = []
AUC_collecton = []
AP=[]

mean_recall = np.linspace(0, 1, 100)
all_precision = []
base_fpr = np.linspace(0, 1, 100)
mean_tpr = 0.0
interp_tpr_collection = []

losses = []  # Used to store the loss value of each fold
for i in range(2):
    # dataset
    y_train_whole = to_categorical(y_train)
    
    clf = CNN(input_dim, out_dim, 0.001)
    hist = clf.fit(X_train, y_train_whole, batch_size=64, epochs=120)

    # save model
    # model_path = os.path.join(model_save_dir, f'ESM_{i}.h5')
    # clf.save(model_path)
    # print(f'Model for fold {i+1} saved at {model_path}')

    losses.append(hist.history['loss'])  # Record the loss value of each epoch

    y_score = clf.predict(X_test)
    y_class = categorical_probas_to_classes(y_score)
    TP, FP, FN, TN = confusion_matrix(y_test, y_class).ravel() # shape [ [True-Positive, False-positive], [False-negative, True-negative] ]
    Sn_collecton.append(TP/(TP+FN))
    Sp_collecton.append(TN/(TN+FP))
    MCC = (TP*TN-FP*FN)/math.pow(((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN)),0.5)
    MCC_collecton.append(MCC)
    BACC_collecton.append(0.5*TP/(TP+FN)+0.5*TN/(TN+FP))
    ACC = (TP+TN)/(TP+TN+FP+FN)
    ACC_collecton.append(ACC)
    # ROC curve
    fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
    interp_tpr = np.interp(base_fpr, fpr, tpr)
    interp_tpr[0] = 0.0
    interp_tpr_collection.append(interp_tpr)
    auc_roc = auc(fpr, tpr)
    AUC_collecton.append(auc_roc)
    # PR curve
    precision, recall, _ = precision_recall_curve(y_test, y_score[:, 1])
    average_precision = average_precision_score(y_test, y_score[:, 1])
    recall = np.flipud(recall)
    precision = np.flipud(precision)

    mean_precision = np.interp(mean_recall, recall, precision)
    all_precision.append(mean_precision)
    AP.append(average_precision)


# After all cross-validation cycles are completed, the mean TPR is calculated.
mean_tpr = np.mean(interp_tpr_collection, axis=0)
mean_tpr[-1] = 1.0

# Calculate the mean precision
mean_precision = np.mean(all_precision, axis=0)

# Output
results = [
    f"ACC: {round(statistics.mean(ACC_collecton), 3)} ± {round(statistics.stdev(ACC_collecton), 3)}",
    f"BACC: {round(statistics.mean(BACC_collecton), 3)} ± {round(statistics.stdev(BACC_collecton), 3)}",
    f"Sn: {round(statistics.mean(Sn_collecton), 3)} ± {round(statistics.stdev(Sn_collecton), 3)}",
    f"Sp: {round(statistics.mean(Sp_collecton), 3)} ± {round(statistics.stdev(Sp_collecton), 3)}",
    f"MCC: {round(statistics.mean(MCC_collecton), 3)} ± {round(statistics.stdev(MCC_collecton), 3)}",
    f"AUC: {round(statistics.mean(AUC_collecton), 3)} ± {round(statistics.stdev(AUC_collecton), 3)}",
    f"AP: {round(statistics.mean(AP), 3)} ± {round(statistics.stdev(AP), 3)}"
]

for result in results:
    print(result)

# Append the results to the file
with open('result/results_CNN.txt', 'a') as file:
    file.write("----------------------------------------\n")
    for result in results:
        file.write(result + '\n')
# Out:
# Epoch 1/120
# 22/22 [==============================] - 6s 8ms/step - loss: 0.6808 - accuracy: 0.5943
# Epoch 2/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6293 - accuracy: 0.6553
# Epoch 3/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5925 - accuracy: 0.6705
# Epoch 4/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5718 - accuracy: 0.7039
# Epoch 5/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5535 - accuracy: 0.7061
# Epoch 6/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5435 - accuracy: 0.7192
# Epoch 7/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5285 - accuracy: 0.7235
# Epoch 8/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5348 - accuracy: 0.7155
# Epoch 9/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5221 - accuracy: 0.7293
# Epoch 10/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.7475
# Epoch 11/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4928 - accuracy: 0.7518
# Epoch 12/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4888 - accuracy: 0.7591
# Epoch 13/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4863 - accuracy: 0.7533
# Epoch 14/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4699 - accuracy: 0.7663
# Epoch 15/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4573 - accuracy: 0.7779
# Epoch 16/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4730 - accuracy: 0.7656
# Epoch 17/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4375 - accuracy: 0.8070
# Epoch 18/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4386 - accuracy: 0.7794
# Epoch 19/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4259 - accuracy: 0.7946
# Epoch 20/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4017 - accuracy: 0.8186
# Epoch 21/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3960 - accuracy: 0.8193
# Epoch 22/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3814 - accuracy: 0.8345
# Epoch 23/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3694 - accuracy: 0.8324
# Epoch 24/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3539 - accuracy: 0.8476
# Epoch 25/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3640 - accuracy: 0.8440
# Epoch 26/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3505 - accuracy: 0.8454
# Epoch 27/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3234 - accuracy: 0.8570
# Epoch 28/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3347 - accuracy: 0.8570
# Epoch 29/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3142 - accuracy: 0.8672
# Epoch 30/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3279 - accuracy: 0.8549
# Epoch 31/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3008 - accuracy: 0.8766
# Epoch 32/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3055 - accuracy: 0.8650
# Epoch 33/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2848 - accuracy: 0.8788
# Epoch 34/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2790 - accuracy: 0.8868
# Epoch 35/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2714 - accuracy: 0.8810
# Epoch 36/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2576 - accuracy: 0.8919
# Epoch 37/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2539 - accuracy: 0.9057
# Epoch 38/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2408 - accuracy: 0.9035
# Epoch 39/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2320 - accuracy: 0.9020
# Epoch 40/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2298 - accuracy: 0.9071
# Epoch 41/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2220 - accuracy: 0.9100
# Epoch 42/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2159 - accuracy: 0.9202
# Epoch 43/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2123 - accuracy: 0.9158
# Epoch 44/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1973 - accuracy: 0.9245
# Epoch 45/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2111 - accuracy: 0.9078
# Epoch 46/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2019 - accuracy: 0.9224
# Epoch 47/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1707 - accuracy: 0.9354
# Epoch 48/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1832 - accuracy: 0.9274
# Epoch 49/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1773 - accuracy: 0.9274
# Epoch 50/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1696 - accuracy: 0.9311
# Epoch 51/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1579 - accuracy: 0.9434
# Epoch 52/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1600 - accuracy: 0.9376
# Epoch 53/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1510 - accuracy: 0.9390
# Epoch 54/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1561 - accuracy: 0.9369
# Epoch 55/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2233 - accuracy: 0.9144
# Epoch 56/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2498 - accuracy: 0.8977
# Epoch 57/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1865 - accuracy: 0.9253
# Epoch 58/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1638 - accuracy: 0.9427
# Epoch 59/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1269 - accuracy: 0.9572
# Epoch 60/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1304 - accuracy: 0.9514
# Epoch 61/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1199 - accuracy: 0.9507
# Epoch 62/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.9557
# Epoch 63/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1236 - accuracy: 0.9543
# Epoch 64/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1237 - accuracy: 0.9492
# Epoch 65/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1333 - accuracy: 0.9463
# Epoch 66/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1588 - accuracy: 0.9267
# Epoch 67/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1360 - accuracy: 0.9485
# Epoch 68/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1367 - accuracy: 0.9456
# Epoch 69/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1001 - accuracy: 0.9608
# Epoch 70/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1019 - accuracy: 0.9630
# Epoch 71/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9673
# Epoch 72/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1105 - accuracy: 0.9550
# Epoch 73/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0958 - accuracy: 0.9630
# Epoch 74/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1044 - accuracy: 0.9630
# Epoch 75/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0999 - accuracy: 0.9608
# Epoch 76/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0812 - accuracy: 0.9710
# Epoch 77/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 0.9579
# Epoch 78/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1137 - accuracy: 0.9565
# Epoch 79/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1046 - accuracy: 0.9565
# Epoch 80/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0958 - accuracy: 0.9652
# Epoch 81/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0773 - accuracy: 0.9688
# Epoch 82/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0759 - accuracy: 0.9746
# Epoch 83/120
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0746 - accuracy: 0.9761
# Epoch 84/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0884 - accuracy: 0.9673
# Epoch 85/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0757 - accuracy: 0.9695
# Epoch 86/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0634 - accuracy: 0.9768
# Epoch 87/120
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9731
# Epoch 88/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0902 - accuracy: 0.9644
# Epoch 89/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1103 - accuracy: 0.9536
# Epoch 90/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1072 - accuracy: 0.9565
# Epoch 91/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.9521
# Epoch 92/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0874 - accuracy: 0.9623
# Epoch 93/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0880 - accuracy: 0.9688
# Epoch 94/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0705 - accuracy: 0.9761
# Epoch 95/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0710 - accuracy: 0.9761
# Epoch 96/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0583 - accuracy: 0.9804
# Epoch 97/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0543 - accuracy: 0.9819
# Epoch 98/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9790
# Epoch 99/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 0.9731
# Epoch 100/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.9833
# Epoch 101/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0600 - accuracy: 0.9790
# Epoch 102/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0552 - accuracy: 0.9811
# Epoch 103/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0580 - accuracy: 0.9797
# Epoch 104/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 0.9797
# Epoch 105/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0880 - accuracy: 0.9623
# Epoch 106/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1116 - accuracy: 0.9528
# Epoch 107/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0711 - accuracy: 0.9731
# Epoch 108/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0496 - accuracy: 0.9819
# Epoch 109/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9833
# Epoch 110/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 0.9848
# Epoch 111/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9855
# Epoch 112/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0382 - accuracy: 0.9898
# Epoch 113/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0455 - accuracy: 0.9862
# Epoch 114/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0489 - accuracy: 0.9826
# Epoch 115/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0501 - accuracy: 0.9833
# Epoch 116/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0469 - accuracy: 0.9848
# Epoch 117/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0420 - accuracy: 0.9833
# Epoch 118/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0340 - accuracy: 0.9862
# Epoch 119/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0496 - accuracy: 0.9782
# Epoch 120/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.9833
# Epoch 1/120
# 22/22 [==============================] - 1s 4ms/step - loss: 0.6790 - accuracy: 0.5472
# Epoch 2/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6243 - accuracy: 0.6560
# Epoch 3/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5957 - accuracy: 0.6691
# Epoch 4/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5770 - accuracy: 0.6814
# Epoch 5/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5517 - accuracy: 0.6930
# Epoch 6/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5454 - accuracy: 0.7112
# Epoch 7/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5312 - accuracy: 0.7199
# Epoch 8/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5162 - accuracy: 0.7271
# Epoch 9/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5041 - accuracy: 0.7388
# Epoch 10/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5020 - accuracy: 0.7366
# Epoch 11/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4888 - accuracy: 0.7525
# Epoch 12/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4786 - accuracy: 0.7656
# Epoch 13/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4726 - accuracy: 0.7656
# Epoch 14/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4528 - accuracy: 0.7794
# Epoch 15/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4451 - accuracy: 0.7837
# Epoch 16/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4419 - accuracy: 0.7859
# Epoch 17/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4250 - accuracy: 0.7888
# Epoch 18/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.8135
# Epoch 19/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3966 - accuracy: 0.8164
# Epoch 20/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4017 - accuracy: 0.8048
# Epoch 21/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3810 - accuracy: 0.8266
# Epoch 22/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3710 - accuracy: 0.8389
# Epoch 23/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3928 - accuracy: 0.8186
# Epoch 24/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3554 - accuracy: 0.8498
# Epoch 25/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3637 - accuracy: 0.8280
# Epoch 26/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3436 - accuracy: 0.8447
# Epoch 27/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3342 - accuracy: 0.8672
# Epoch 28/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3243 - accuracy: 0.8643
# Epoch 29/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3137 - accuracy: 0.8599
# Epoch 30/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3139 - accuracy: 0.8679
# Epoch 31/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3072 - accuracy: 0.8665
# Epoch 32/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2984 - accuracy: 0.8766
# Epoch 33/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3025 - accuracy: 0.8716
# Epoch 34/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2874 - accuracy: 0.8810
# Epoch 35/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2552 - accuracy: 0.9035
# Epoch 36/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2571 - accuracy: 0.9042
# Epoch 37/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2630 - accuracy: 0.8890
# Epoch 38/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2403 - accuracy: 0.9136
# Epoch 39/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2317 - accuracy: 0.9122
# Epoch 40/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2304 - accuracy: 0.9049
# Epoch 41/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2300 - accuracy: 0.9165
# Epoch 42/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2133 - accuracy: 0.9158
# Epoch 43/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1894 - accuracy: 0.9303
# Epoch 44/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1890 - accuracy: 0.9267
# Epoch 45/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1781 - accuracy: 0.9332
# Epoch 46/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1702 - accuracy: 0.9376
# Epoch 47/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1641 - accuracy: 0.9347
# Epoch 48/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1666 - accuracy: 0.9347
# Epoch 49/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1581 - accuracy: 0.9398
# Epoch 50/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1574 - accuracy: 0.9383
# Epoch 51/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1516 - accuracy: 0.9405
# Epoch 52/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1843 - accuracy: 0.9253
# Epoch 53/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1585 - accuracy: 0.9383
# Epoch 54/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9528
# Epoch 55/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1286 - accuracy: 0.9594
# Epoch 56/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1406 - accuracy: 0.9456
# Epoch 57/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1131 - accuracy: 0.9630
# Epoch 58/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1113 - accuracy: 0.9608
# Epoch 59/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1158 - accuracy: 0.9543
# Epoch 60/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1211 - accuracy: 0.9565
# Epoch 61/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1174 - accuracy: 0.9572
# Epoch 62/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1028 - accuracy: 0.9673
# Epoch 63/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0906 - accuracy: 0.9666
# Epoch 64/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0824 - accuracy: 0.9746
# Epoch 65/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1241 - accuracy: 0.9499
# Epoch 66/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1228 - accuracy: 0.9470
# Epoch 67/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1080 - accuracy: 0.9630
# Epoch 68/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9717
# Epoch 69/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0985 - accuracy: 0.9623
# Epoch 70/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1862 - accuracy: 0.9202
# Epoch 71/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1434 - accuracy: 0.9376
# Epoch 72/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0906 - accuracy: 0.9695
# Epoch 73/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0625 - accuracy: 0.9826
# Epoch 74/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 0.9790
# Epoch 75/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0615 - accuracy: 0.9782
# Epoch 76/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9797
# Epoch 77/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0706 - accuracy: 0.9753
# Epoch 78/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.9615
# Epoch 79/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0716 - accuracy: 0.9797
# Epoch 80/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0647 - accuracy: 0.9761
# Epoch 81/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0533 - accuracy: 0.9848
# Epoch 82/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0509 - accuracy: 0.9826
# Epoch 83/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0570 - accuracy: 0.9797
# Epoch 84/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0591 - accuracy: 0.9782
# Epoch 85/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0595 - accuracy: 0.9790
# Epoch 86/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0519 - accuracy: 0.9840
# Epoch 87/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0413 - accuracy: 0.9855
# Epoch 88/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 0.9949
# Epoch 89/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0378 - accuracy: 0.9884
# Epoch 90/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0355 - accuracy: 0.9877
# Epoch 91/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9891
# Epoch 92/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 0.9891
# Epoch 93/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 0.9782
# Epoch 94/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0660 - accuracy: 0.9739
# Epoch 95/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 0.9869
# Epoch 96/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0420 - accuracy: 0.9877
# Epoch 97/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0533 - accuracy: 0.9797
# Epoch 98/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 0.9942
# Epoch 99/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0445 - accuracy: 0.9819
# Epoch 100/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0470 - accuracy: 0.9848
# Epoch 101/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0514 - accuracy: 0.9855
# Epoch 102/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.9855
# Epoch 103/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0367 - accuracy: 0.9891
# Epoch 104/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0510 - accuracy: 0.9840
# Epoch 105/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0330 - accuracy: 0.9877
# Epoch 106/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0452 - accuracy: 0.9855
# Epoch 107/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 0.9913
# Epoch 108/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9891
# Epoch 109/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9884
# Epoch 110/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 0.9891
# Epoch 111/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0345 - accuracy: 0.9877
# Epoch 112/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 0.9869
# Epoch 113/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0572 - accuracy: 0.9819
# Epoch 114/120
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0604 - accuracy: 0.9746
# Epoch 115/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0575 - accuracy: 0.9790
# Epoch 116/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0590 - accuracy: 0.9775
# Epoch 117/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0724 - accuracy: 0.9768
# Epoch 118/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1158 - accuracy: 0.9507
# Epoch 119/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0952 - accuracy: 0.9637
# Epoch 120/120
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0539 - accuracy: 0.9819
# ACC: 0.721 ± 0.004
# BACC: 0.722 ± 0.004
# Sn: 0.724 ± 0.013
# Sp: 0.719 ± 0.02
# MCC: 0.442 ± 0.008
# AUC: 0.797 ± 0.005
# AP: 0.78 ± 0.004

# %%
# 绘制ROC曲线
plt.figure()
lw = 2
plt.plot(base_fpr, mean_tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % np.mean(AUC_collecton))
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Independence test')
plt.legend(loc="lower right")
plt.tight_layout()
# plt.savefig('loss_curve.png', dpi=300)
plt.show()

# %%
# 绘制损失函数曲线
from matplotlib.ticker import FuncFormatter


# 字体设置
plt.rcParams['font.family'] = 'Times New Roman'

n = 0
loss = losses[n]
plt.figure(figsize=(6, 4))

plt.plot(loss)
# for i, loss in enumerate(losses):
#     plt.plot(loss, label=f'Fold {i+1}')

formatter = FuncFormatter(lambda x, pos: f'{x:.2f}')
plt.gca().yaxis.set_major_formatter(formatter)

plt.xlabel('Epoch', fontsize=15)
plt.ylabel('', fontsize=15)
plt.title('CNN', fontsize=18)
plt.legend()
plt.tight_layout()
plt.savefig('graph\Loss\ACP_CNN_120.jpeg', dpi=300)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### 结尾
